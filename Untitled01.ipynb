# %% [markdown]
# <a href="https://colab.research.google.com/github/shaikzuberulla/python_fundamentals01/blob/main/Untitled01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('Salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
type (df)
# Out:
# pandas.core.frame.DataFrame

# %%
# prompt: import basic library  pandas and then read the file/content/Salaries.csv

import pandas as pd
df = pd.read_csv('Salaries.csv')
df
type(df)

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
# prompt: Using dataframe df: head function

# Display the first 10 rows of the dataframe
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.tail(10)
# Out:
#          rank discipline  phd  service     sex  salary
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.shape
# Out:
# (78, 6)

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# ..    ...         ...    ...      ...    ...     ...
# 73  False       False  False    False  False   False
# 74  False       False  False    False  False   False
# 75  False       False  False    False  False   False
# 76  False       False  False    False  False   False
# 77  False       False  False    False  False   False
#
# [78 rows x 6 columns]

# %%
df.isnull().any()
# Out:
# rank          False
# discipline    False
# phd           False
# service       False
# sex           False
# salary        False
# dtype: bool

# %%
df['salary'].mean()
# Out:
# 108023.78205128205

# %%
# prompt: can you find the mean for salary column

df['salary'].mean()
# Out:
# 108023.78205128205

# %%
df['salary'].median()
# Out:
# 104671.0

# %%
df['salary'].mode()
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
df['salary'].var()
# Out:
# 800531254.0427904

# %%
df['salary'].std()
# Out:
# 28293.661022264165

# %%
# prompt: can you find out basic stats information such as mean, median , mode, variance , std , skewness, kurtosis , range

import pandas as pd
import numpy as np
from scipy.stats import skew, kurtosis

df = pd.read_csv('Salaries.csv')

# Calculate the mean
mean_salary = df['salary'].mean()

# Calculate the median
median_salary = df['salary'].median()

# Calculate the mode
mode_salary = df['salary'].mode()[0]  # Access the first element if multiple modes exist

# Calculate the variance
variance_salary = df['salary'].var()

# Calculate the standard deviation
std_salary = df['salary'].std()

# Calculate the skewness
skewness_salary = skew(df['salary'])

# Calculate the kurtosis
kurtosis_salary = kurtosis(df['salary'])

# Calculate the range
range_salary = df['salary'].max() - df['salary'].min()


print(f"Mean: {mean_salary}")
print(f"Median: {median_salary}")
print(f"Mode: {mode_salary}")
print(f"Variance: {variance_salary}")
print(f"Standard Deviation: {std_salary}")
print(f"Skewness: {skewness_salary}")
print(f"Kurtosis: {kurtosis_salary}")
print(f"Range: {range_salary}")
# Out:
# Mean: 108023.78205128205
# Median: 104671.0
# Mode: 92000
# Variance: 800531254.0427904
# Standard Deviation: 28293.661022264165
# Skewness: 0.443361422461378
# Kurtosis: -0.4523692672246771
# Range: 129160

# %%
df[df['salary']> 50000]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.iloc[:,:]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.iloc[0:10,:]
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
# prompt: can you select 1st 10 records and all the columns from my datafreme df and show me the output

# Select the first 10 rows and all columns
df_first_10 = df.iloc[:10, :]

# Display the output
df_first_10
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.mean(numeric_only=True)
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.groupby('rank').mean(numeric_only=True)
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby('rank')[['salary', 'service', 'phd']].mean()
# Out:
#                   salary    service        phd
# rank
# AssocProf   91786.230769  11.307692  15.076923
# AsstProf    81362.789474   2.210526   5.052632
# Prof       123624.804348  21.413043  27.065217

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv('Universities.csv')

# %%
df1
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
plt.hist(df1['SAT'])
plt.xlabel('SAT Score')
plt.ylabel('Frequency')
plt.title('Distribution of SAT Scores')
plt.show()

# %%
sns.histplot(df1['Accept'])
plt.show()

# %%
# prompt: con you create a histogram on accept column in dataframe df1 using seaborn library

sns.histplot(df1['Accept'])
plt.xlabel('Accept')
plt.ylabel('Frequency')
plt.title('Distribution of Accept')
plt.show()

# %%
plt.plot(df1['Accept'], df1['SAT'], 'bo')
plt.xlabel('Accept')
plt.ylabel('SAT')
plt.title('Scatter Plot of Accept vs SAT')
plt.show()

# %%
sns.pairplot(df1)

# %%
sns.pairplot(df1.iloc[:,1:3])

# %%
sns.distplot(df1['Accept'])
# Out:
# <ipython-input-24-12fa4e5e46c5>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['Accept'])
# <Axes: xlabel='Accept', ylabel='Density'>

# %%
# prompt: con you write a narrative summary in the box plot of accept column in dataframe df1

# Assuming you have a DataFrame named df1 with an 'Accept' column
plt.figure(figsize=(8, 6))
sns.boxplot(x=df1['Accept'])
plt.title('Box Plot of Accept')
plt.xlabel('Accept')
plt.show()

# Narrative summary based on the box plot:
# The box plot of the "Accept" column in df1 appears to show a somewhat skewed distribution with potential outliers.
# The median (represented by the line within the box) appears to be located around [estimate the median from the plot].
# The interquartile range (IQR), represented by the box itself, indicates that the majority of accept values lie between [estimate the lower quartile from the plot] and [estimate the upper quartile from the plot].
# The whiskers extend to [estimate the ends of the whiskers from the plot], with potential outliers shown as individual points beyond the whiskers.
# The presence of potential outliers suggests that some universities have unusually high or low acceptance rates compared to the rest of the universities in the dataset.
# Further analysis may be needed to understand the nature of these outliers.

# %%
# prompt: con you create a boxplot on accept column in dataframe df1


sns.boxplot(x=df1['Accept'])
plt.title('Box Plot of Accept')
plt.xlabel('Accept')
plt.show()

# %%
import numpy as np

# %%
a= np.array([1,2,3,4,5,6])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.shape
# Out:
# (6,)

# %%
a.shape
# Out:
# (6,)

# %%
a.sum()
# Out:
# 21

# %%
a.prod()
# Out:
# 720

# %%
a.min()
# Out:
# 1

# %%
a.max()
# Out:
# 6

# %%
b=np.array([[1,2,3],[4,5,6]])

# %%
b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
type(b)
# Out:
# numpy.ndarray

# %%
b.shape
# Out:
# (2, 3)

# %%
b.size
# Out:
# 6

# %%
b= b.reshape(3,2)

# %%
b
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
b[0]
# Out:
# array([1, 2])

# %%
b.sum(axis=0)
# Out:
# array([ 9, 12])

# %%
b.sum(axis=1)
# Out:
# array([ 3,  7, 11])
